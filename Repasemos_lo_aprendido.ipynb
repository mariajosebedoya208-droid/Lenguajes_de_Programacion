# %% [markdown]
# # 📊 Repaso de Listas en Python - Aplicación Financiera
#
# En este notebook repasaremos **listas en Python** aplicándolas a un análisis de **viabilidad financiera**.
#
# Aprenderás a:
# - Crear listas
# - Acceder a elementos
# - Agregar y eliminar elementos
# - Modificar listas
# - Usar slicing
# - Validar resultados con Python

# %% [markdown]
# # Ejercicio 1
#
# Crear una lista llamada acciones, con las siguientes acciones: Apple, Microsoft, Amazon, Google

# %%
acciones = ["Apple", "Microsoft", "Amazon", "Google"]

# %% [markdown]
# ## crear una listas de precios

# %%
precios= [150, 250, 120]

# %% [markdown]
# ## Como conocer la posicion de un elemento en una lista?

# %%
acciones.index("Microsoft")
# Out:
# 1

# %% [markdown]
# # Como puedo conocer el tamaño de una lista?

# %%
acciones
# Out:
# ['Apple', 'Microsoft', 'Amazon', 'Google']

# %%
len(acciones)
# Out:
# 4

# %% [markdown]
# # Como añadir un elemento a la lista? al final de acciones?

# %%
acciones.append("Tesla")

# %%
acciones
# Out:
# ['Apple', 'Microsoft', 'Amazon', 'Google', 'Tesla']

# %% [markdown]
# ## Como puedo eliminar el elemento de la lista, si tento el elemento, Google

# %%
acciones.remove("Google") # Se esta eliminando un elemento de la lista

# %%
acciones
# Out:
# ['Apple', 'Microsoft', 'Amazon', 'Tesla']

# %% [markdown]
# ## Eliminar el elemento que se encuentra en la 3 posicion

# %%
acciones.pop(3)
print (acciones)
# Out:
# ['Apple', 'Microsoft', 'Amazon']

# %%
tasa_interes=[0.5,0.98,0.03]

# %% [markdown]
# ## Como puedo multiplicar dos listas, tasa_ intereses y la precios

# %%
sumar_listas= tasa_interes + precios
print(sumar_listas)
# Out:
# [0.5, 0.98, 0.03, 150, 250, 120]

# %% [markdown]
# ## como se define una tupla

# %%
empresas=("microso","google")

# %% [markdown]
# ## Cual es la diferencia lista de la tupla?

# %%
listas= []
tupla=()
diccionario={}
